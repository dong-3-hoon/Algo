# %%
T = int(input())
# 여러개의 테스트 케이스가 주어지므로, 각각을 처리합니다.
for test_case in range(1, T + 1):
    cnt=1
    lst=[] #생성 스도쿠 배열
    for i in range(9):# 배열 생성
        lst.append(list(map(int, input().split())))
    sset=set([])
    for j in range(9): #x축 스도쿠 검증
        for k in lst[j]:
            sset.add(k)
        if len(sset) < 9:
            cnt=0
        sset=set([])
    for a in range(9): #y축 스도쿠 검증
        for b in range(9):
            sset.add(lst[b][a])
        if len(sset) < 9:
            cnt=0
        sset=set([])
    x=0
    y=0
    for y in range(3):#1,1번
        for x in range(3):
            sset.add(lst[x][y])
    if len(sset) < 9:
        cnt=0
    sset=set([])
    
    for y in range(3):#2,1번
        for x in range(3,6):
            sset.add(lst[x][y])
    if len(sset) < 9:
        cnt=0
    sset=set([])

    for y in range(3):#3,1
        for x in range(6,9):
            sset.add(lst[x][y])
    if len(sset) < 9:
        cnt=0
    sset=set([])
    
    for y in range(3,6):#2,1
        for x in range(3):
            sset.add(lst[x][y])
    if len(sset) < 9:
        cnt=0
    sset=set([])

    for y in range(3,6):#2,2
        for x in range(3,6):
            sset.add(lst[x][y])
    if len(sset) < 9:
        cnt=0
    sset=set([])

    for y in range(3,6):#2,3
        for x in range(6,9):
            sset.add(lst[x][y])
    if len(sset) < 9:
        cnt=0
    sset=set([])

    for y in range(6,9):#3,1
        for x in range(3):
            sset.add(lst[x][y])
    if len(sset) < 9:
        cnt=0
    sset=set([])
    
    for y in range(6,9):#3,2
        for x in range(3,6):
            sset.add(lst[x][y])
    if len(sset) < 9:
        cnt=0
    sset=set([])
    
    for y in range(6,9):#3,3
        for x in range(6,9):
            sset.add(lst[x][y])
    if len(sset) < 9:
        cnt=0
    sset=set([])
    
    print(f"#{test_case} {cnt}")
